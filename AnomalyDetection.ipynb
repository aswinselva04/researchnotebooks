# %% [markdown]
# ### Exploratory

# %%
overall_data = pd.read_excel('tfcu_member.xlsx', index_col=0, sheet_name='KPI Data')

# %%
overall_data.drop()
# Out:
#           Emp First Name Emp Last Name    Emp Mobile            Emp Email Id  \
# Emp Id
# NaN                  NaN           NaN           NaN                     NaN
# NaN                  NaN           NaN           NaN                     NaN
# NaN                  NaN           NaN           NaN                     NaN
# TCFU-0001          Apple       William  631-385 8791  apple.william@tcfu.com
# TCFU-0002            Bri         James  631-385 1161      bri.james@tcfu.com
#
#           Emp Designation     Branch Branch Manager First Name  \
# Emp Id
# NaN                   NaN        NaN                       NaN
# NaN                   NaN        NaN                       NaN
# NaN                   NaN        NaN                       NaN
# TCFU-0001             FSR  Bay Shore                    Oliver
# TCFU-0002             FSR  Patchogue                     Banks
#
#           Branch Manager Last  Name   Week Unnamed: 10  ... Decline rate  \
# Emp Id                                                  ...
# NaN                             NaN    NaN         UOM  ...            %
# NaN                             NaN    NaN      Target  ...            5
# NaN                             NaN    NaN    Category  ...           LB
# TCFU-0001                      Ivan  WK 01         NaN  ...            4
# TCFU-0002                    Thelma  WK 01         NaN  ...            2
#
#           Financial impact due to attacks  \
# Emp Id
# NaN                                   USD
# NaN                                  5600
# NaN                                    LB
# TCFU-0001                           17659
# TCFU-0002                            7176
#
#           Attempted vs Fraudulent Transactions Final Approval rate  \
# Emp Id
# NaN                                          %                   %
# NaN                                          6                  80
# NaN                                         LB                  MB
# TCFU-0001                                    9                  82
# TCFU-0002                                    9                  79
#
#           Fraudulent Vs Declined Transactions System Uptime  \
# Emp Id
# NaN                                         %             %
# NaN                                        85            98
# NaN                                        MB            MB
# TCFU-0001                                  82            91
# TCFU-0002                                  79            98
#
#           Severity of attacks Mean Time Between Failures (MTBF)  \
# Emp Id
# NaN                    Rating                              Days
# NaN                         3                                90
# NaN                        LB                                MB
# TCFU-0001                   6                                93
# TCFU-0002                  10                                37
#
#           Cost per incident Number of cybersecurity incidents reported
# Emp Id
# NaN                     USD                                     Number
# NaN                    7000                                          1
# NaN                      LB                                         LB
# TCFU-0001              6160                                          3
# TCFU-0002              8560                                          6
#
# [5 rows x 30 columns]

# %%
overall_data.columns
# Out:
# Index(['Emp First Name', 'Emp Last Name', 'Emp Mobile', 'Emp Email Id',
#        'Emp Designation', 'Branch', 'Branch Manager First Name',
#        'Branch Manager Last  Name', 'Week', 'Unnamed: 10', 'Member Retention',
#        'Employee Retention', 'Member Satisfaction NPS', 'Fraud rate',
#        'Employee satisfaction', 'Number of Employee Relations Issues',
#        '# of Member complaints', 'Member acquisition cost (CAC)',
#        'Number of Compliance Issues', 'Compliance Investigation Cycle Time',
#        'Decline rate', 'Financial impact due to attacks',
#        'Attempted vs Fraudulent Transactions', 'Final Approval rate',
#        'Fraudulent Vs Declined Transactions', 'System Uptime',
#        'Severity of attacks', 'Mean Time Between Failures (MTBF)',
#        'Cost per incident', 'Number of cybersecurity incidents reported'],
#       dtype='object')

# %%
# rows_to_drop = [0 2]
overall_data.drop(overall_data.index[0:3])
# Out:
#           Emp First Name Emp Last Name    Emp Mobile  \
# Emp Id
# TCFU-0001          Apple       William  631-385 8791
# TCFU-0002            Bri         James  631-385 1161
# TCFU-0003         Alaska        Robert  631-385 1994
# TCFU-0004          Ariel        Joseph  631-385 8476
# TCFU-0005      Bridgette        George  631-385 8743
# ...                  ...           ...           ...
# TCFU-0396        Zachary          Lela  529-101 0270
# TCFU-0397            Roy        Thomas  529-101 0271
# TCFU-0398           Toby        Walter  529-101 0272
# TCFU-0399           Zeke        Harold  529-101 0273
# TCFU-0400           Theo         Henry  529-101 0274
#
#                         Emp Email Id Emp Designation        Branch  \
# Emp Id
# TCFU-0001     apple.william@tcfu.com             FSR     Bay Shore
# TCFU-0002         bri.james@tcfu.com             FSR     Patchogue
# TCFU-0003     alaska.robert@tcfu.com             FSR    Amityville
# TCFU-0004      ariel.joseph@tcfu.com             FSR    Amityville
# TCFU-0005  bridgette.george@tcfu.com             FSR     Riverhead
# ...                              ...             ...           ...
# TCFU-0396      zachary.lela@tcfu.com             FSR   Rocky Point
# TCFU-0397        roy.thomas@tcfu.com             FSR  Wading River
# TCFU-0398       toby.walter@tcfu.com             FSR     Patchogue
# TCFU-0399       zeke.harold@tcfu.com             FSR    Kings Park
# TCFU-0400        theo.henry@tcfu.com             FSR  So. Setauket
#
#           Branch Manager First Name Branch Manager Last  Name   Week  \
# Emp Id
# TCFU-0001                    Oliver                      Ivan  WK 01
# TCFU-0002                     Banks                    Thelma  WK 01
# TCFU-0003                      Liam                   Wilfred  WK 01
# TCFU-0004                      Liam                   Wilfred  WK 01
# TCFU-0005                    Wylder                     Edith  WK 01
# ...                             ...                       ...    ...
# TCFU-0396                    Kylian                     Doris  WK 52
# TCFU-0397                      John                      Pete  WK 52
# TCFU-0398                     Banks                    Thelma  WK 52
# TCFU-0399                      Ozzy                     Merle  WK 52
# TCFU-0400                     Zyair                    Esther  WK 52
#
#           Unnamed: 10  ... Decline rate Financial impact due to attacks  \
# Emp Id                 ...
# TCFU-0001         NaN  ...            4                           17659
# TCFU-0002         NaN  ...            2                            7176
# TCFU-0003         NaN  ...           10                           19038
# TCFU-0004         NaN  ...            1                           16007
# TCFU-0005         NaN  ...            1                            9574
# ...               ...  ...          ...                             ...
# TCFU-0396         NaN  ...           13                           10330
# TCFU-0397         NaN  ...            6                           22104
# TCFU-0398         NaN  ...           11                           13977
# TCFU-0399         NaN  ...            9                           11454
# TCFU-0400         NaN  ...           14                           21806
#
#           Attempted vs Fraudulent Transactions Final Approval rate  \
# Emp Id
# TCFU-0001                                    9                  82
# TCFU-0002                                    9                  79
# TCFU-0003                                    6                  73
# TCFU-0004                                   10                  85
# TCFU-0005                                   10                  77
# ...                                        ...                 ...
# TCFU-0396                                    5                  75
# TCFU-0397                                    7                  83
# TCFU-0398                                    6                  82
# TCFU-0399                                   11                  82
# TCFU-0400                                   12                  81
#
#           Fraudulent Vs Declined Transactions System Uptime  \
# Emp Id
# TCFU-0001                                  82            91
# TCFU-0002                                  79            98
# TCFU-0003                                  73            96
# TCFU-0004                                  85            95
# TCFU-0005                                  77            94
# ...                                       ...           ...
# TCFU-0396                                  75            96
# TCFU-0397                                  83            98
# TCFU-0398                                  82            98
# TCFU-0399                                  82            95
# TCFU-0400                                  81            96
#
#           Severity of attacks Mean Time Between Failures (MTBF)  \
# Emp Id
# TCFU-0001                   6                                93
# TCFU-0002                  10                                37
# TCFU-0003                   2                                12
# TCFU-0004                   9                                95
# TCFU-0005                   4                                13
# ...                       ...                               ...
# TCFU-0396                   8                                31
# TCFU-0397                   1                                16
# TCFU-0398                   2                                20
# TCFU-0399                   8                                35
# TCFU-0400                   2                               100
#
#           Cost per incident Number of cybersecurity incidents reported
# Emp Id
# TCFU-0001              6160                                          3
# TCFU-0002              8560                                          6
# TCFU-0003              7274                                          2
# TCFU-0004              7221                                          6
# TCFU-0005              5420                                          5
# ...                     ...                                        ...
# TCFU-0396              9541                                          1
# TCFU-0397              8299                                          0
# TCFU-0398              9598                                          1
# TCFU-0399              8394                                          4
# TCFU-0400              9775                                          4
#
# [20800 rows x 30 columns]

# %%
df_ = overall_data.drop(overall_data.index[0:3])

# %%
df_.columns
# Out:
# Index(['Emp First Name', 'Emp Last Name', 'Emp Mobile', 'Emp Email Id',
#        'Emp Designation', 'Branch', 'Branch Manager First Name',
#        'Branch Manager Last  Name', 'Week', 'Unnamed: 10', 'Member Retention',
#        'Employee Retention', 'Member Satisfaction NPS', 'Fraud rate',
#        'Employee satisfaction', 'Number of Employee Relations Issues',
#        '# of Member complaints', 'Member acquisition cost (CAC)',
#        'Number of Compliance Issues', 'Compliance Investigation Cycle Time',
#        'Decline rate', 'Financial impact due to attacks',
#        'Attempted vs Fraudulent Transactions', 'Final Approval rate',
#        'Fraudulent Vs Declined Transactions', 'System Uptime',
#        'Severity of attacks', 'Mean Time Between Failures (MTBF)',
#        'Cost per incident', 'Number of cybersecurity incidents reported'],
#       dtype='object')

# %%
df = df_.drop(columns=['Unnamed: 10'])

# %%
df.head()
# Out:
#           Emp First Name Emp Last Name    Emp Mobile  \
# Emp Id
# TCFU-0001          Apple       William  631-385 8791
# TCFU-0002            Bri         James  631-385 1161
# TCFU-0003         Alaska        Robert  631-385 1994
# TCFU-0004          Ariel        Joseph  631-385 8476
# TCFU-0005      Bridgette        George  631-385 8743
#
#                         Emp Email Id Emp Designation      Branch  \
# Emp Id
# TCFU-0001     apple.william@tcfu.com             FSR   Bay Shore
# TCFU-0002         bri.james@tcfu.com             FSR   Patchogue
# TCFU-0003     alaska.robert@tcfu.com             FSR  Amityville
# TCFU-0004      ariel.joseph@tcfu.com             FSR  Amityville
# TCFU-0005  bridgette.george@tcfu.com             FSR   Riverhead
#
#           Branch Manager First Name Branch Manager Last  Name   Week  \
# Emp Id
# TCFU-0001                    Oliver                      Ivan  WK 01
# TCFU-0002                     Banks                    Thelma  WK 01
# TCFU-0003                      Liam                   Wilfred  WK 01
# TCFU-0004                      Liam                   Wilfred  WK 01
# TCFU-0005                    Wylder                     Edith  WK 01
#
#           Member Retention  ... Decline rate Financial impact due to attacks  \
# Emp Id                      ...
# TCFU-0001               95  ...            4                           17659
# TCFU-0002               94  ...            2                            7176
# TCFU-0003               86  ...           10                           19038
# TCFU-0004               70  ...            1                           16007
# TCFU-0005               90  ...            1                            9574
#
#           Attempted vs Fraudulent Transactions Final Approval rate  \
# Emp Id
# TCFU-0001                                    9                  82
# TCFU-0002                                    9                  79
# TCFU-0003                                    6                  73
# TCFU-0004                                   10                  85
# TCFU-0005                                   10                  77
#
#           Fraudulent Vs Declined Transactions System Uptime  \
# Emp Id
# TCFU-0001                                  82            91
# TCFU-0002                                  79            98
# TCFU-0003                                  73            96
# TCFU-0004                                  85            95
# TCFU-0005                                  77            94
#
#           Severity of attacks Mean Time Between Failures (MTBF)  \
# Emp Id
# TCFU-0001                   6                                93
# TCFU-0002                  10                                37
# TCFU-0003                   2                                12
# TCFU-0004                   9                                95
# TCFU-0005                   4                                13
#
#           Cost per incident Number of cybersecurity incidents reported
# Emp Id
# TCFU-0001              6160                                          3
# TCFU-0002              8560                                          6
# TCFU-0003              7274                                          2
# TCFU-0004              7221                                          6
# TCFU-0005              5420                                          5
#
# [5 rows x 29 columns]

# %%
df_time = df[['Week','Member Retention',
       'Employee Retention', 'Member Satisfaction NPS', 'Fraud rate',
       'Employee satisfaction', 'Number of Employee Relations Issues',
       '# of Member complaints', 'Member acquisition cost (CAC)',
       'Number of Compliance Issues', 'Compliance Investigation Cycle Time',
       'Decline rate', 'Financial impact due to attacks',
       'Attempted vs Fraudulent Transactions', 'Final Approval rate',
       'Fraudulent Vs Declined Transactions', 'System Uptime',
       'Severity of attacks', 'Mean Time Between Failures (MTBF)',
       'Cost per incident', 'Number of cybersecurity incidents reported'
             ]].groupby(['Week']).mean()

# %%
df_time.head()
# Out:
#       Member Retention Employee Retention Member Satisfaction NPS Fraud rate  \
# Week
# WK 01          74.3875              75.02                   62.36   0.475584
# WK 02           74.405            74.3275                 62.0125   0.473602
# WK 03           73.115             75.195                  62.365   0.505365
# WK 04           75.265            74.0125                 62.4525   0.462778
# WK 05          74.3925              73.94                 63.4925   0.507319
#
#       Employee satisfaction Number of Employee Relations Issues  \
# Week
# WK 01                5.3525                               2.915
# WK 02                  5.64                                3.06
# WK 03                 5.615                                3.04
# WK 04                  5.67                               3.025
# WK 05                 5.695                               2.905
#
#       # of Member complaints Member acquisition cost (CAC)  \
# Week
# WK 01                10.5675                          86.5
# WK 02                  9.815                       86.2725
# WK 03                10.3625                       88.7375
# WK 04                  9.625                       88.8675
# WK 05                 9.6375                       86.5575
#
#       Number of Compliance Issues Compliance Investigation Cycle Time  \
# Week
# WK 01                        2.49                               18.31
# WK 02                      2.4675                               18.24
# WK 03                        2.49                              19.195
# WK 04                       2.325                              19.655
# WK 05                      2.4025                               18.51
#
#       Decline rate Financial impact due to attacks  \
# Week
# WK 01        7.745                         14709.1
# WK 02       8.1175                      15483.0525
# WK 03        8.075                       14896.315
# WK 04         8.02                       14942.675
# WK 05        8.195                      14797.1975
#
#       Attempted vs Fraudulent Transactions Final Approval rate  \
# Week
# WK 01                                8.585             79.6875
# WK 02                                8.425              80.255
# WK 03                               8.4125             79.9725
# WK 04                                8.545               80.06
# WK 05                               8.4325               79.93
#
#       Fraudulent Vs Declined Transactions System Uptime Severity of attacks  \
# Week
# WK 01                             79.6875       94.3775              5.4725
# WK 02                              80.255       94.8075                5.38
# WK 03                             79.9725       94.4925               5.545
# WK 04                               80.06         94.55                5.33
# WK 05                               79.93        94.625              5.6775
#
#       Mean Time Between Failures (MTBF) Cost per incident  \
# Week
# WK 01                           55.2675          7535.725
# WK 02                            54.945         7414.5425
# WK 03                            56.075         7331.6025
# WK 04                             57.56         7444.6875
# WK 05                            56.495           7455.96
#
#       Number of cybersecurity incidents reported
# Week
# WK 01                                     2.9575
# WK 02                                       3.08
# WK 03                                     3.1425
# WK 04                                      3.055
# WK 05                                       2.95

# %%
df_time.plot.line(y = 'Member Retention')
# Out:
# <Axes: xlabel='Week'>

# %%
'Employee Retention', 'Member Satisfaction NPS', 'Fraud rate',
       'Employee satisfaction', 'Number of Employee Relations Issues',
       '# of Member complaints', 'Member acquisition cost (CAC)',
       'Number of Compliance Issues', 'Compliance Investigation Cycle Time',
       'Decline rate', 'Financial impact due to attacks',
       'Attempted vs Fraudulent Transactions', 'Final Approval rate',
       'Fraudulent Vs Declined Transactions', 'System Uptime',
       'Severity of attacks', 'Mean Time Between Failures (MTBF)',
       'Cost per incident', 'Number of cybersecurity incidents reported'

# %%
df_time.plot.line(y='Employee Retention')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Member Satisfaction NPS')
# Out:
# <Axes: xlabel='Week'>

# %% [markdown]
# #### Member Satisfaction NPS has an anomaly

# %%
df_time.plot.line(y = 'Fraud rate')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Number of Employee Relations Issues')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = '# of Member complaints')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Member acquisition cost (CAC)')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Number of Compliance Issues')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Compliance Investigation Cycle Time')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Decline rate')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Financial impact due to attacks')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Attempted vs Fraudulent Transactions')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y='Final Approval rate')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y='Fraudulent Vs Declined Transactions')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y='System Uptime')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y='Severity of attacks')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y='Mean Time Between Failures (MTBF)')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Cost per incident')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Number of cybersecurity incidents reported')
# Out:
# <Axes: xlabel='Week'>

# %%
df_time.plot.line(y = 'Member Satisfaction NPS')

# %%
df_anomaly = df_time['Member Satisfaction NPS']

# %%
df_anomaly['WK 20']
# Out:
# 59.99

# %%
df_anomaly.plot()
# Out:
# <Axes: xlabel='Week'>

# %% [markdown]
# ### Method 1: Isolation Forest

# %%
import pandas as pd
daily_min_temp = pd.read_csv('daily-min-temperatures.csv')
daily_min_temp.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
len(daily_min_temp)
# Out:
# 3650

# %%
daily_min_temp.describe()
# Out:
#               Temp
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %%
daily_min_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3650 non-null   object
#  1   Temp    3650 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 57.2+ KB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest

# %%
outliers_fraction = float(.01)
scaler = StandardScaler()
np_scaled = scaler.fit_transform(df_anomaly.values.reshape(-1, 1))

# %%
data = pd.DataFrame(np_scaled)

# %%
data.head()
# Out:
#           0
# 0 -0.336088
# 1 -0.859858
# 2 -0.328552
# 3 -0.196667
# 4  1.370874

# %%
model =  IsolationForest(contamination=outliers_fraction)
model.fit(data)
# Out:
# IsolationForest(contamination=0.01)

# %%
df_anomaly = pd.DataFrame(df_anomaly, columns=['Member Satisfaction NPS'])

# %%
df_anomaly['anomaly'] = model.predict(data)

# %%
fig, ax = plt.subplots(figsize=(10,6))
a = df_anomaly.loc[df_anomaly['anomaly'] == -1, ['Member Satisfaction NPS']] #anomaly
ax.plot(df_anomaly.index, df_anomaly['Member Satisfaction NPS'], color='gray', label = 'Normal')
ax.scatter(a.index,a['Member Satisfaction NPS'], color='red', label = 'Anomaly')
plt.legend()
plt.show();

# %% [markdown]
# ### Medthod 2: Seasonal Decomposition

# %%
df_anomaly_stl = pd.DataFrame(df_time['Member Satisfaction NPS'], columns=['Member Satisfaction NPS'])

# %%
df_anomaly_stl.head()
# Out:
#       Member Satisfaction NPS
# Week
# WK 01                   62.36
# WK 02                 62.0125
# WK 03                  62.365
# WK 04                 62.4525
# WK 05                 63.4925

# %%
# df_anomaly_stl.index = df_anomaly_stl.index.map(lambda x: x + ' 0 1970')

# %%
df_anomaly_stl.index.values
# Out:
# array(['WK 01', 'WK 02', 'WK 03', 'WK 04', 'WK 05', 'WK 06', 'WK 07',
#        'WK 08', 'WK 09', 'WK 10', 'WK 11', 'WK 12', 'WK 13', 'WK 14',
#        'WK 15', 'WK 16', 'WK 17', 'WK 18', 'WK 19', 'WK 20', 'WK 21',
#        'WK 22', 'WK 23', 'WK 24', 'WK 25', 'WK 26', 'WK 27', 'WK 28',
#        'WK 29', 'WK 30', 'WK 31', 'WK 32', 'WK 33', 'WK 34', 'WK 35',
#        'WK 36', 'WK 37', 'WK 38', 'WK 39', 'WK 40', 'WK 41', 'WK 42',
#        'WK 43', 'WK 44', 'WK 45', 'WK 46', 'WK 47', 'WK 48', 'WK 49',
#        'WK 50', 'WK 51', 'WK 52'], dtype=object)

# %%
# df_anomaly_stl.index = pd.to_datetime(df_anomaly_stl.index, format='WK %U')
# df_anomaly_stl.index = pd.to_datetime(df_anomaly_stl.index.values, format='WK %U %j %Y')
# df_anomaly_stl.index = pd.to_datetime(df_anomaly_stl.index.values, errors='coerce')

# %%
df_anomaly_stl.index = df_anomaly_stl.index.map(lambda x: '2023 '+x + ' 1')

# %%
df_anomaly_stl.index
# Out:
# DatetimeIndex(['2023-01-02', '2023-01-09', '2023-01-16', '2023-01-23',
#                '2023-01-30', '2023-02-06', '2023-02-13', '2023-02-20',
#                '2023-02-27', '2023-03-06', '2023-03-13', '2023-03-20',
#                '2023-03-27', '2023-04-03', '2023-04-10', '2023-04-17',
#                '2023-04-24', '2023-05-01', '2023-05-08', '2023-05-15',
#                '2023-05-22', '2023-05-29', '2023-06-05', '2023-06-12',
#                '2023-06-19', '2023-06-26', '2023-07-03', '2023-07-10',
#                '2023-07-17', '2023-07-24', '2023-07-31', '2023-08-07',
#                '2023-08-14', '2023-08-21', '2023-08-28', '2023-09-04',
#                '2023-09-11', '2023-09-18', '2023-09-25', '2023-10-02',
#                '2023-10-09', '2023-10-16', '2023-10-23', '2023-10-30',
#                '2023-11-06', '2023-11-13', '2023-11-20', '2023-11-27',
#                '2023-12-04', '2023-12-11', '2023-12-18', '2023-12-25'],
#               dtype='datetime64[ns]', name='Week', freq=None)

# %%
import datetime

# %%
df_anomaly_stl.index = df_anomaly_stl.index.map(lambda x: datetime.datetime.strptime(x, "%Y WK %W %w"))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
plt.rc('figure',figsize=(12,8))
plt.rc('font',size=15)
result = seasonal_decompose(df_anomaly_stl,model='additive', period = 4)
fig = result.plot()

# %%
result.resid.to_frame()
# Out:
#                resid
# Week
# 2023-01-02       NaN
# 2023-01-09       NaN
# 2023-01-16 -0.182702
# 2023-01-23 -0.047441
# 2023-01-30  0.760033
# 2023-02-06 -0.578952
# 2023-02-13  0.113236
# 2023-02-20  0.303184
# 2023-02-27 -0.965280
# 2023-03-06  1.431048
# 2023-03-13 -0.895202
# 2023-03-20 -0.105879
# 2023-03-27  0.254095
# 2023-04-03  0.467611
# 2023-04-10 -0.755827
# 2023-04-17  0.265371
# 2023-04-24  0.275658
# 2023-05-01 -0.002702
# 2023-05-08  0.448236
# 2023-05-15 -1.933066
# 2023-05-22  1.063470
# 2023-05-29  0.621361
# 2023-06-05 -0.428014
# 2023-06-12 -0.540879
# 2023-06-19  0.325345
# 2023-06-26  0.095736
# 2023-07-03  0.477611
# 2023-07-10 -0.104941
# 2023-07-17 -0.534655
# 2023-07-24 -0.106452
# 2023-07-31  0.604173
# 2023-08-07 -0.044941
# 2023-08-14  0.296595
# 2023-08-21 -0.602389
# 2023-08-28 -0.376139
# 2023-09-04  0.809434
# 2023-09-11 -0.084967
# 2023-09-18 -0.843952
# 2023-09-25  0.328548
# 2023-10-02  0.522559
# 2023-10-09  0.015033
# 2023-10-16 -0.343014
# 2023-10-23 -0.219577
# 2023-10-30  0.780059
# 2023-11-06 -0.857467
# 2023-11-13  0.118548
# 2023-11-20  0.808236
# 2023-11-27  0.019121
# 2023-12-04 -0.625280
# 2023-12-11 -0.334264
# 2023-12-18       NaN
# 2023-12-25       NaN

# %%
result_df = result.resid.to_frame()

# %%
result_df.head()
# Out:
#                resid
# Week
# 2023-01-02       NaN
# 2023-01-09       NaN
# 2023-01-16 -0.182702
# 2023-01-23 -0.047441
# 2023-01-30  0.760033

# %%
result25 = result_df['resid'].quantile(0.25)
result75 = result_df['resid'].quantile(0.75)
# percentile75 = df['placement_exam_marks'].quantile(0.75)

# %%
result25, result75
# Out:
# (-0.38910807291666477, 0.35847005208332855)

# %%
IQR = result75 - result25

# %%
IQR
# Out:
# 0.7475781249999933

# %%
Q1 = result25
Q3 = result75

low_lim = Q1 - 1.5 * IQR
up_lim = Q3 + 1.5 * IQR
print('low_limit is', low_lim)
print('up_limit is', up_lim)
# Out:
# low_limit is -1.5104752604166547
# up_limit is 1.4798372395833186

# %%
result_df.loc[(result_df['resid'].lt(low_lim))]
# Out:
#                resid
# Week
# 2023-05-15 -1.933066

# %%
result_df.loc[(result_df['resid'].gt(up_lim))]
# Out:
# Empty DataFrame
# Columns: [resid]
# Index: []

# %%
df_anomaly_stl.loc['2023-05-15']
# Out:
# Member Satisfaction NPS    59.99
# Name: 2023-05-15 00:00:00, dtype: object

# %% [markdown]
# #### STL decompose method

# %%
from statsmodels.tsa.seasonal import STL

stl = STL(df_anomaly_stl, seasonal=13)  # Adjust the seasonal parameter as needed
result = stl.fit()

# %%
plt.rc('figure',figsize=(12,8))
plt.rc('font',size=15)
# result = seasonal_decompose(df_anomaly_stl,model='additive', two_sided=True)
fig = result.plot()

# %%
import matplotlib.dates as mdates

# %%
result.resid
# Out:
# Week
# 2023-01-02    0.000000e+00
# 2023-01-09   -1.421085e-14
# 2023-01-16    1.421085e-14
# 2023-01-23   -1.421085e-14
# 2023-01-30   -1.421085e-14
# 2023-02-06   -7.105427e-15
# 2023-02-13    0.000000e+00
# 2023-02-20   -1.421085e-14
# 2023-02-27    0.000000e+00
# 2023-03-06    0.000000e+00
# 2023-03-13    0.000000e+00
# 2023-03-20   -1.421085e-14
# 2023-03-27    0.000000e+00
# 2023-04-03    0.000000e+00
# 2023-04-10   -7.105427e-15
# 2023-04-17    0.000000e+00
# 2023-04-24   -1.421085e-14
# 2023-05-01    0.000000e+00
# 2023-05-08    7.105427e-15
# 2023-05-15   -7.105427e-15
# 2023-05-22   -1.421085e-14
# 2023-05-29   -1.421085e-14
# 2023-06-05   -1.421085e-14
# 2023-06-12    0.000000e+00
# 2023-06-19   -7.105427e-15
# 2023-06-26   -7.105427e-15
# 2023-07-03    0.000000e+00
# 2023-07-10    7.105427e-15
# 2023-07-17    0.000000e+00
# 2023-07-24   -7.105427e-15
# 2023-07-31   -1.421085e-14
# 2023-08-07   -7.105427e-15
# 2023-08-14   -1.421085e-14
# 2023-08-21   -1.421085e-14
# 2023-08-28   -7.105427e-15
# 2023-09-04   -1.421085e-14
# 2023-09-11   -7.105427e-15
# 2023-09-18    0.000000e+00
# 2023-09-25   -1.421085e-14
# 2023-10-02   -1.421085e-14
# 2023-10-09   -7.105427e-15
# 2023-10-16   -7.105427e-15
# 2023-10-23   -1.421085e-14
# 2023-10-30   -1.421085e-14
# 2023-11-06   -1.421085e-14
# 2023-11-13   -7.105427e-15
# 2023-11-20   -1.421085e-14
# 2023-11-27   -1.421085e-14
# 2023-12-04    0.000000e+00
# 2023-12-11   -7.105427e-15
# 2023-12-18   -1.421085e-14
# 2023-12-25   -7.105427e-15
# Name: resid, dtype: float64

# %%
# plt.rc('figure',figsize=(12,6))
# plt.rc('font',size=15)

# fig, ax = plt.subplots()
# x = result.resid.index
# y = result.resid.values
# ax.plot_date(x, y, color='black',linestyle='--')

# ax.annotate('Anomaly', (mdates.date2num(x[35]), y[35]), xytext=(30, 20), 
#            textcoords='offset points', color='red',arrowprops=dict(facecolor='red',arrowstyle='fancy'))

# fig.autofmt_xdate()
# plt.show()

# %% [markdown]
# ### Method 3: Robust Z-Score

# %%
from scipy.stats import median_abs_deviation
import pandas as pd
import numpy as np

# %%
overall_data = pd.read_excel('tfcu_member.xlsx', index_col=0, sheet_name='KPI Data')
df_ = overall_data.drop(overall_data.index[0:3])
df = df_.drop(columns=['Unnamed: 10'])
df_time = df[['Week','Member Retention',
       'Employee Retention', 'Member Satisfaction NPS', 'Fraud rate',
       'Employee satisfaction', 'Number of Employee Relations Issues',
       '# of Member complaints', 'Member acquisition cost (CAC)',
       'Number of Compliance Issues', 'Compliance Investigation Cycle Time',
       'Decline rate', 'Financial impact due to attacks',
       'Attempted vs Fraudulent Transactions', 'Final Approval rate',
       'Fraudulent Vs Declined Transactions', 'System Uptime',
       'Severity of attacks', 'Mean Time Between Failures (MTBF)',
       'Cost per incident', 'Number of cybersecurity incidents reported'
             ]].groupby(['Week']).mean()

# %%
df_anomaly = pd.DataFrame(df_time['Member Satisfaction NPS'])
mad = median_abs_deviation(df_anomaly['Member Satisfaction NPS'])
median = np.median(df_anomaly['Member Satisfaction NPS'])
mad, median
# Out:
# (0.40000000000000213, 62.63125)

# %%
def robust_z_score(x):
    return 0.6745 * (x - median)/mad

df_anomaly['z_score'] = df_anomaly['Member Satisfaction NPS'].apply(robust_z_score)

# %%
df_anomaly['anomaly'] = 0
df_anomaly.loc[df_anomaly['z_score']>=3.5, 'anomaly'] = 1
df_anomaly.loc[df_anomaly['z_score']<=-3.5, 'anomaly'] = 1

# %%
df_anomaly[df_anomaly['anomaly']==1]
# Out:
#        Member Satisfaction NPS   z_score  anomaly
# Week
# WK 20                    59.99 -4.453808        1

# %% [markdown]
# ### Method 4: Local Outlier factor

# %%
from sklearn.neighbors import LocalOutlierFactor
df_anomaly_loc = pd.DataFrame(df_time['Member Satisfaction NPS'])

from sklearn.neighbors import LocalOutlierFactor

clf = LocalOutlierFactor(n_neighbors=5, contamination=0.1)
y_pred = clf.fit_predict(df_anomaly_loc)

# %%
df_anomaly_loc['anomaly'] = y_pred

# %%
df_anomaly_loc[df_anomaly_loc['anomaly'] == -1]
# Out:
#        Member Satisfaction NPS  anomaly
# Week
# WK 10                  63.8675       -1
# WK 20                  59.9900       -1
# WK 21                  63.2375       -1
# WK 23                  62.2275       -1
# WK 25                  63.1525       -1
# WK 45                  62.1800       -1

# %%
clf = LocalOutlierFactor(n_neighbors=30, contamination=0.01)
y_pred = clf.fit_predict(df_anomaly_loc.dropna())
df_anomaly_loc['anomaly'] = y_pred
df_anomaly_loc[df_anomaly_loc['anomaly'] == -1]
# Out:
#        Member Satisfaction NPS  anomaly
# Week
# WK 20                    59.99       -1

# %% [markdown]
# ### Method 5: Prophet - bayesian changepoint and linear regression

# %%
import datetime
df_anomaly_prop = pd.DataFrame(df_time['Member Satisfaction NPS'], columns=['Member Satisfaction NPS'])
df_anomaly_prop.index = df_anomaly_prop.index.map(lambda x: '2023 '+x + ' 1')
df_anomaly_prop.index = df_anomaly_prop.index.map(lambda x: datetime.datetime.strptime(x, "%Y WK %W %w"))

# %%
df_anomaly_prop.head()
# Out:
#             Member Satisfaction NPS
# Week
# 2023-01-02                  62.3600
# 2023-01-09                  62.0125
# 2023-01-16                  62.3650
# 2023-01-23                  62.4525
# 2023-01-30                  63.4925

# %%
df_anomaly_prop.index.names = ['ds']

# %%
df_anomaly_prop = df_anomaly_prop.rename(columns={"Member Satisfaction NPS": "y"})

# %%
df_anomaly_prop = df_anomaly_prop.reset_index()

# %%
df_anomaly_prop.head()
# Out:
#           ds        y
# 0 2023-01-02  62.3600
# 1 2023-01-09  62.0125
# 2 2023-01-16  62.3650
# 3 2023-01-23  62.4525
# 4 2023-01-30  63.4925

# %%
import pandas as pd
import prophet as Prophet
import matplotlib.pyplot as plt

import os
# os.chdir('drive/My Drive')

# file_path = 'Prophet+TS+data.csv'
# data = pd.read_csv(file_path)
data = df_anomaly_prop

def fit_predict_model(dataframe, interval_width = 0.99, changepoint_range = 0.8):
    m = Prophet.Prophet(daily_seasonality = False, yearly_seasonality = False, weekly_seasonality = False,
                seasonality_mode = 'multiplicative', 
                interval_width = interval_width,
                changepoint_range = changepoint_range)
    m = m.fit(dataframe)
    
    forecast = m.predict(dataframe)
    forecast['fact'] = dataframe['y'].reset_index(drop = True)
    print('Displaying Prophet plot')
    fig1 = m.plot(forecast)
    return forecast
    
pred = fit_predict_model(data)

def detect_anomalies(forecast):
    forecasted = forecast[['ds','trend', 'yhat', 'yhat_lower', 'yhat_upper', 'fact']].copy()
    #forecast['fact'] = df['y']

    forecasted['anomaly'] = 0
    forecasted.loc[forecasted['fact'] > forecasted['yhat_upper'], 'anomaly'] = 1
    forecasted.loc[forecasted['fact'] < forecasted['yhat_lower'], 'anomaly'] = -1

    #anomaly importances
    forecasted['importance'] = 0
    forecasted.loc[forecasted['anomaly'] ==1, 'importance'] = \
        (forecasted['fact'] - forecasted['yhat_upper'])/forecast['fact']
    forecasted.loc[forecasted['anomaly'] ==-1, 'importance'] = \
        (forecasted['yhat_lower'] - forecasted['fact'])/forecast['fact']
    
    return forecasted

pred = detect_anomalies(pred)
pred.head()

pd.plotting.register_matplotlib_converters()  # needed to plot timestamps
pred.plot(x='ds', y=['fact', 'yhat', 'yhat_upper', 'yhat_lower'])
plt.title('Anomaly Detection')
plt.xlabel('Date')
plt.ylabel('Member Satisfaction NPS')
plt.show()
# Out:
# 20:04:14 - cmdstanpy - INFO - Chain [1] start processing
# 20:04:14 - cmdstanpy - INFO - Chain [1] done processing
# Displaying Prophet plot

# %%
anomaly_data = pred[(pred['anomaly'] == -1 ) | (pred['anomaly'] == 1) ]
anomaly_data
# Out:
#            ds      trend       yhat  yhat_lower  yhat_upper   fact  anomaly  \
# 19 2023-05-15  62.541623  62.541623   60.883484   64.121123  59.99       -1
#
#     importance
# 19    0.014894
